# %%
import sys
sys.path.append('../')
import os
import numpy as np
import matplotlib.pyplot as plt
import glob
from modules.shrec import utils,cvae_parameters, cvae, experiment, experiment_parameters, shrec2019utils, generator_images, cvae_basic
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define the parameters for training
# Train a Conditional Variational Autoencoder with a VGG-like architecture using a fixed number of downsampling and upsampling layers (num encoding layers and num decoding layers). Each of the convolutions in the network has a certain number of filters given in terms of the intermediate dim parameter. Other parameters include:
#
# - **epochs**: Number of epochs for training
# - **batch_size**: Number of images per batch of training
# - **type_layer**: Type of layers used in the encoding and decoding networ. Either "convolutional" or "dense"
# - **num_encoding_layers**: Number of the max pooling layers in the encoding network
# - **num_decoding_layers**: Number of the upsampling layers in the decoding network
# - **var_x**: Variance of the normal distribution for p(x|z,y)
# - **r_loss**: Type of loss chosen for reconstruction (either binary cross entropy "binary" or mean squared error "mse")
# - **latent_dim**: Dimensions of the latent space of the conditional variational autoencoder
# - **intermediate_dim** Defines the number of filters in the case of the convolutions or the number of neurons in a convolutional or dense layer respectively.
# - **learning_rate**: Learning rate of the optimizer used
# - **image_shape**: Shape of the images used for training

# %%
epochs = 500
batch_size = 700
type_layer = "convolutional"
num_encoding_layers = 3
num_decoding_layers = 3
intermediate_dim  =  64
num_classes = 10
latent_dim = 100
learning_rate = 0.001
image_shape = (64,64,3)
var_x = 1.0

# %% [markdown]
# ### Define data generator
# The training of the network is done via a generator. The generator is created from a list of the paths to the corresponding images.

# %%
main_directory = os.path.dirname(os.getcwd())
dataset_directory = os.path.join(main_directory, "dataset")
path_class_files = os.path.join(dataset_directory, "class_files")
# Read the file with the names of the models and images that will be used for training
cla_file_path_renders = os.path.join(path_class_files, "SceneIBR2018_Model_Training.cla")
cla_file_path_photographs = os.path.join(path_class_files, "SceneIBR2018_Image_Training.cla")

# Paths to the corresponding images folder
renders_path = os.path.join(dataset_directory,"renders_64")
photos_path = os.path.join(dataset_directory,"images_64")

# Renders
categories, model_lists = shrec2019utils.obtain_models_classes(cla_file_path_renders)
categories_array, models_array = shrec2019utils.categories_model_list_to_array(categories, model_lists)
# Photographs
categories_photographs, model_lists_photographs = shrec2019utils.obtain_models_classes2018(cla_file_path_photographs)
categories_array_photographs, models_array_photographs = shrec2019utils.categories_model_list_to_array(categories_photographs, model_lists_photographs)

print("Categories of renders {} amount {}".format(np.unique(categories), len(np.unique(categories))))
print("Categories of images {} amount {}".format(np.unique(categories_photographs), len(np.unique(categories_photographs))))
print("Amount of renders {}".format(len(models_array)))
print("Amount of images {}".format(len(models_array_photographs)))
# Out:
# Initial index barn 0 70
# Initial index beach 0 70
# Initial index bedroom 0 70
# Initial index castle 0 70
# Initial index classroom 0 70
# Initial index desert 0 70
# Initial index kitchen 0 70
# Initial index library 0 70
# Initial index mountain 0 70
# Initial index river 0 70
# Initial index barn 0 700
# Initial index beach 0 700
# Initial index bedroom 0 700
# Initial index castle 0 700
# Initial index classroom 0 700
# Initial index desert 0 700
# Initial index kitchen 0 700
# Initial index library 0 700
# Initial index mountain 0 700
# Initial index river 0 700
# Categories of renders ['barn' 'beach' 'bedroom' 'castle' 'classroom' 'desert' 'kitchen'
#  'library' 'mountain' 'river'] amount 10
# Categories of images ['barn' 'beach' 'bedroom' 'castle' 'classroom' 'desert' 'kitchen'
#  'library' 'mountain' 'river'] amount 10
# Amount of renders 700
# Amount of images 7000

# %% [markdown]
# ### Join identifiers for rendered images and photographs
#
# Create a list comprising both, the identifiers for the renders and the images used for training.

# %%
# Join the paths for the training renders and photographs
images_paths = []
joint_categories = []
type_data = []
for num_model, model in enumerate(models_array):
    for image_path in glob.glob(os.path.join(renders_path,  str(model)+'_*.png')):
        images_paths.append(image_path)
        joint_categories.append(categories_array[num_model])
        type_data.append("render")
number_of_renders = len(images_paths)
print("Amount of renders ",number_of_renders)   
for num_model, model in enumerate(models_array_photographs):
    for image_path in glob.glob(os.path.join(photos_path,  str(model)+'.png')):
        images_paths.append(image_path)
        joint_categories.append(categories_array_photographs[num_model])
        type_data.append("photograph")
number_of_photographs = len(images_paths)-number_of_renders
print("Amount of photographs ",number_of_photographs)
# Out:
# Amount of renders  9100
# Amount of photographs  7000

# %%
# Join the categories for each of the paths
joint_categories = np.array(joint_categories)
joint_categories = shrec2019utils.categories_array_to_numerical(joint_categories)
# Transform the categories to one hot encodings
joint_categories = utils.one_hotify(joint_categories)
print("Joint categories length {}".format(len(joint_categories)))
print("Joint paths length {}".format(len(images_paths)))

# Create the generator

dim = (image_shape[0], image_shape[1]) # resolution of the images
n_channels = image_shape[2] # number of color channels
generator = generator_images.ShrecGenerator(images_paths, joint_categories, dim= (64,64), n_channels = 3, batch_size=batch_size, n_classes = num_classes, flatten=False, reflect=True)
# Out:
# Joint categories length 16100
# Joint paths length 16100

# %% [markdown]
# ### Training of Conditional Variational Autoencoder
# In this section an instance of the conditional variational autoencoder class is defined with respect to the parameters previously defined. The class containes the encoding and decoding neural network of the conditional variational autoencoder.

# %%
# DEFINE THE NETWORK OF THE CONDITIONAL VARIATIONAL AUTOENCODER
cvae_parameters_dict = {"image_shape": image_shape,# shape of the input images
                       "num_classes": num_classes, # number of classes for the scenes
                       "type_layers":type_layer,# either "convolutional neural network" or "dense neural network"
                       "num_encoding_layers": num_encoding_layers, # number of the max pooling layers in the encoding
                       "num_decoding_layers": num_decoding_layers, # number of the upsampling layers in the decoding
                       "var_x":var_x, # variance of the normal distribution for p(x|z,y)
                       "r_loss":"binary", # type of loss chosen (either binary cross entropy "binary" or mean squared error "mse")
                       "latent_dim":latent_dim, # dimensions of the latent space of the conditional variational autoencoder
                       "intermediate_dim":intermediate_dim, # defines the number of filters in the convolutions
                       "learning_rate":learning_rate # learning rate of the optimizer
                       }
# Define the parameters for the CVAE
parameters = cvae_parameters.CVAEParams(**cvae_parameters_dict)
# Define the CVAE
cond_vae = cvae_basic.CVAE_Basic(parameters)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1029 08:50:16.563773 140382105212736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Convolutional
# W1029 08:50:17.085240 140382105212736 deprecation_wrapper.py:119] From /home/luis/shrec_modules/cvae_shrec/modules/shrec/cvae.py:140: The name tf.log is deprecated. Please use tf.math.log instead.
# Reconstruction loss is binary cross entropy
# Reconstruction loss is binary cross entropy

# %% [markdown]
# ### Start training experiment
# Define an experiment for training. The experiment takes the instance of the conditional variational autoencoder, the experiment parameters and a folder for saving the tensorboard log files and the trained model weights.

# %%
# Define the parameters for training
experiment_params_dict = {"epochs": epochs,
                         "batch_size": batch_size}
exp_parameters  = experiment_parameters.ExperimentParams(**experiment_params_dict)

# Define an experiment
saving_model_folder = os.path.join(main_directory, "trained_models","simple_submission")

exp = experiment.Experiment(cond_vae, exp_parameters, None, saving_model_folder)

exp.run_image_generator(generator) # Training of the CVAE with the generator as a source of data
# Out:
# Epoch 1/500
#  - 32s - loss: 8004.9685 - r_loss: 8004.8911 - kl_loss: 0.0023 - mean_squared_error: 0.0928 - classification_loss: 0.0758
# Epoch 2/500
#  - 31s - loss: 8004.9676 - r_loss: 8004.8892 - kl_loss: 0.0018 - mean_squared_error: 0.0928 - classification_loss: 0.0767
# Epoch 3/500
#  - 32s - loss: 8004.9471 - r_loss: 8004.8740 - kl_loss: 0.0016 - mean_squared_error: 0.0928 - classification_loss: 0.0728
# Epoch 4/500
#  - 32s - loss: 8004.9461 - r_loss: 8004.8770 - kl_loss: 0.0017 - mean_squared_error: 0.0928 - classification_loss: 0.0667
# Epoch 5/500
#  - 32s - loss: 8004.9482 - r_loss: 8004.8809 - kl_loss: 0.0021 - mean_squared_error: 0.0928 - classification_loss: 0.0651
# Epoch 6/500
#  - 32s - loss: 8004.9346 - r_loss: 8004.8711 - kl_loss: 0.0011 - mean_squared_error: 0.0928 - classification_loss: 0.0615
# Epoch 7/500
#  - 32s - loss: 8004.9349 - r_loss: 8004.8711 - kl_loss: 0.0013 - mean_squared_error: 0.0928 - classification_loss: 0.0633
# Epoch 8/500
#  - 31s - loss: 8004.9357 - r_loss: 8004.8755 - kl_loss: 0.0014 - mean_squared_error: 0.0928 - classification_loss: 0.0588
# Epoch 9/500
#  - 32s - loss: 8004.9588 - r_loss: 8004.9014 - kl_loss: 0.0011 - mean_squared_error: 0.0928 - classification_loss: 0.0576
# Epoch 10/500
#  - 31s - loss: 8004.9232 - r_loss: 8004.8633 - kl_loss: 0.0047 - mean_squared_error: 0.0928 - classification_loss: 0.0554
# Epoch 11/500
#  - 32s - loss: 8004.9213 - r_loss: 8004.8628 - kl_loss: 0.0032 - mean_squared_error: 0.0928 - classification_loss: 0.0557
# Epoch 12/500
#  - 31s - loss: 8004.9722 - r_loss: 8004.9136 - kl_loss: 0.0022 - mean_squared_error: 0.0928 - classification_loss: 0.0565
# Epoch 13/500
#  - 31s - loss: 8004.9365 - r_loss: 8004.8779 - kl_loss: 0.0019 - mean_squared_error: 0.0928 - classification_loss: 0.0566
# Epoch 14/500
#  - 31s - loss: 8004.9369 - r_loss: 8004.8770 - kl_loss: 0.0016 - mean_squared_error: 0.0928 - classification_loss: 0.0586
# Epoch 15/500
#  - 31s - loss: 8004.9384 - r_loss: 8004.8779 - kl_loss: 0.0025 - mean_squared_error: 0.0928 - classification_loss: 0.0580
# Epoch 16/500
#  - 31s - loss: 8004.9561 - r_loss: 8004.8730 - kl_loss: 0.0041 - mean_squared_error: 0.0928 - classification_loss: 0.0795
# Epoch 17/500
#  - 32s - loss: 8005.0722 - r_loss: 8004.8882 - kl_loss: 0.0215 - mean_squared_error: 0.0928 - classification_loss: 0.1624
# Epoch 18/500
#  - 32s - loss: 8004.9597 - r_loss: 8004.8721 - kl_loss: 0.0162 - mean_squared_error: 0.0928 - classification_loss: 0.0725
# Epoch 19/500
#  - 31s - loss: 8004.9373 - r_loss: 8004.8711 - kl_loss: 0.0103 - mean_squared_error: 0.0928 - classification_loss: 0.0554
# Epoch 20/500
#  - 32s - loss: 8004.9399 - r_loss: 8004.8652 - kl_loss: 0.0212 - mean_squared_error: 0.0928 - classification_loss: 0.0537
# Epoch 21/500
#  - 31s - loss: 8004.9464 - r_loss: 8004.8604 - kl_loss: 0.0327 - mean_squared_error: 0.0928 - classification_loss: 0.0518
# Epoch 22/500
#  - 32s - loss: 8005.0021 - r_loss: 8004.8618 - kl_loss: 0.0802 - mean_squared_error: 0.0928 - classification_loss: 0.0592
# Epoch 23/500
#  - 32s - loss: 8005.3324 - r_loss: 8004.7305 - kl_loss: 0.3574 - mean_squared_error: 0.0928 - classification_loss: 0.2450
# Epoch 24/500
#  - 32s - loss: 8005.5570 - r_loss: 8004.8096 - kl_loss: 0.2898 - mean_squared_error: 0.0928 - classification_loss: 0.4589
# Epoch 25/500
#  - 31s - loss: 8004.5720 - r_loss: 8004.0664 - kl_loss: 0.2798 - mean_squared_error: 0.0928 - classification_loss: 0.2266
# Epoch 26/500
#  - 32s - loss: 7715.4187 - r_loss: 7629.5742 - kl_loss: 81.1136 - mean_squared_error: 0.0817 - classification_loss: 4.7314
# Epoch 27/500
#  - 32s - loss: 7123.0019 - r_loss: 7035.0405 - kl_loss: 83.2013 - mean_squared_error: 0.0648 - classification_loss: 4.7597
# Epoch 28/500
#  - 31s - loss: 6880.6543 - r_loss: 6791.4702 - kl_loss: 84.5357 - mean_squared_error: 0.0571 - classification_loss: 4.6476
# Epoch 29/500
#  - 32s - loss: 6722.2030 - r_loss: 6637.7339 - kl_loss: 80.5080 - mean_squared_error: 0.0520 - classification_loss: 3.9613
# Epoch 30/500
#  - 32s - loss: 6607.2128 - r_loss: 6524.7163 - kl_loss: 79.0215 - mean_squared_error: 0.0483 - classification_loss: 3.4741
# Epoch 31/500
#  - 32s - loss: 6531.1299 - r_loss: 6450.1108 - kl_loss: 77.8725 - mean_squared_error: 0.0457 - classification_loss: 3.1463
# Epoch 32/500
#  - 31s - loss: 6463.5450 - r_loss: 6382.4248 - kl_loss: 78.1836 - mean_squared_error: 0.0435 - classification_loss: 2.9371
# Epoch 33/500
#  - 32s - loss: 6410.1714 - r_loss: 6328.3618 - kl_loss: 79.0060 - mean_squared_error: 0.0416 - classification_loss: 2.8036
# Epoch 34/500
#  - 32s - loss: 6374.5019 - r_loss: 6292.5122 - kl_loss: 79.2980 - mean_squared_error: 0.0404 - classification_loss: 2.6920
# Epoch 35/500
#  - 31s - loss: 6339.2886 - r_loss: 6255.5083 - kl_loss: 81.2027 - mean_squared_error: 0.0391 - classification_loss: 2.5782
# Epoch 36/500
#  - 31s - loss: 6307.8195 - r_loss: 6222.8496 - kl_loss: 82.4616 - mean_squared_error: 0.0380 - classification_loss: 2.5064
# Epoch 37/500
#  - 32s - loss: 6283.6626 - r_loss: 6197.3687 - kl_loss: 83.8622 - mean_squared_error: 0.0371 - classification_loss: 2.4333
# Epoch 38/500
#  - 31s - loss: 6261.5869 - r_loss: 6173.6255 - kl_loss: 85.5870 - mean_squared_error: 0.0363 - classification_loss: 2.3756
# Epoch 39/500
#  - 32s - loss: 6244.1708 - r_loss: 6155.1426 - kl_loss: 86.7280 - mean_squared_error: 0.0357 - classification_loss: 2.3011
# Epoch 40/500
#  - 31s - loss: 6230.4690 - r_loss: 6139.7798 - kl_loss: 88.4325 - mean_squared_error: 0.0352 - classification_loss: 2.2561
# Epoch 41/500
#  - 31s - loss: 6212.9709 - r_loss: 6121.5410 - kl_loss: 89.2280 - mean_squared_error: 0.0346 - classification_loss: 2.2018
# Epoch 42/500
#  - 32s - loss: 6198.6161 - r_loss: 6105.8740 - kl_loss: 90.5889 - mean_squared_error: 0.0340 - classification_loss: 2.1520
# Epoch 43/500
#  - 32s - loss: 6187.6500 - r_loss: 6093.5938 - kl_loss: 91.9294 - mean_squared_error: 0.0336 - classification_loss: 2.1274
# Epoch 44/500
#  - 32s - loss: 6177.1089 - r_loss: 6081.7593 - kl_loss: 93.2746 - mean_squared_error: 0.0332 - classification_loss: 2.0752
# Epoch 45/500
#  - 32s - loss: 6167.8551 - r_loss: 6071.1143 - kl_loss: 94.6773 - mean_squared_error: 0.0329 - classification_loss: 2.0626
# Epoch 46/500
#  - 32s - loss: 6157.2309 - r_loss: 6059.5234 - kl_loss: 95.6796 - mean_squared_error: 0.0325 - classification_loss: 2.0289
# Epoch 47/500
#  - 31s - loss: 6146.8101 - r_loss: 6048.2075 - kl_loss: 96.6161 - mean_squared_error: 0.0321 - classification_loss: 1.9863
# Epoch 48/500
#  - 31s - loss: 6139.7020 - r_loss: 6040.3340 - kl_loss: 97.3976 - mean_squared_error: 0.0319 - classification_loss: 1.9695
# Epoch 49/500
#  - 32s - loss: 6134.4497 - r_loss: 6034.5659 - kl_loss: 97.9341 - mean_squared_error: 0.0317 - classification_loss: 1.9500
# Epoch 50/500
#  - 31s - loss: 6125.4151 - r_loss: 6024.6802 - kl_loss: 98.8050 - mean_squared_error: 0.0314 - classification_loss: 1.9307
# Epoch 51/500
#  - 32s - loss: 6119.8420 - r_loss: 6018.4473 - kl_loss: 99.4969 - mean_squared_error: 0.0312 - classification_loss: 1.8980
# Epoch 52/500
#  - 31s - loss: 6121.7408 - r_loss: 6019.8652 - kl_loss: 99.9981 - mean_squared_error: 0.0312 - classification_loss: 1.8774
# Epoch 53/500
#  - 31s - loss: 6113.5087 - r_loss: 6011.1250 - kl_loss: 100.5318 - mean_squared_error: 0.0309 - classification_loss: 1.8515
# Epoch 54/500
#  - 31s - loss: 6101.5009 - r_loss: 5998.2139 - kl_loss: 101.4410 - mean_squared_error: 0.0305 - classification_loss: 1.8466
# Epoch 55/500
#  - 31s - loss: 6097.6820 - r_loss: 5994.1118 - kl_loss: 101.7555 - mean_squared_error: 0.0304 - classification_loss: 1.8137
# Epoch 56/500
#  - 32s - loss: 6092.6049 - r_loss: 5988.8960 - kl_loss: 101.9210 - mean_squared_error: 0.0302 - classification_loss: 1.7885
# Epoch 57/500
#  - 32s - loss: 6086.9885 - r_loss: 5982.4829 - kl_loss: 102.7247 - mean_squared_error: 0.0300 - classification_loss: 1.7809
# Epoch 58/500
#  - 31s - loss: 6082.2273 - r_loss: 5977.5278 - kl_loss: 102.9463 - mean_squared_error: 0.0298 - classification_loss: 1.7523
# Epoch 59/500
#  - 31s - loss: 6075.9864 - r_loss: 5970.6113 - kl_loss: 103.6386 - mean_squared_error: 0.0296 - classification_loss: 1.7367
# Epoch 60/500
#  - 31s - loss: 6071.2870 - r_loss: 5965.6431 - kl_loss: 103.9292 - mean_squared_error: 0.0294 - classification_loss: 1.7150
# Epoch 61/500
#  - 32s - loss: 6065.8039 - r_loss: 5959.4844 - kl_loss: 104.6140 - mean_squared_error: 0.0292 - classification_loss: 1.7059
# Epoch 62/500
#  - 31s - loss: 6061.8095 - r_loss: 5954.9663 - kl_loss: 105.1567 - mean_squared_error: 0.0291 - classification_loss: 1.6861
# Epoch 63/500
#  - 32s - loss: 6060.1648 - r_loss: 5953.4355 - kl_loss: 105.0583 - mean_squared_error: 0.0290 - classification_loss: 1.6721
# Epoch 64/500
#  - 31s - loss: 6053.7286 - r_loss: 5945.8145 - kl_loss: 106.2523 - mean_squared_error: 0.0287 - classification_loss: 1.6620
# Epoch 65/500
#  - 31s - loss: 6050.7426 - r_loss: 5942.8369 - kl_loss: 106.2529 - mean_squared_error: 0.0286 - classification_loss: 1.6522
# Epoch 66/500
#  - 32s - loss: 6044.7515 - r_loss: 5935.9941 - kl_loss: 107.1106 - mean_squared_error: 0.0284 - classification_loss: 1.6465
# Epoch 67/500
#  - 32s - loss: 6040.3018 - r_loss: 5931.3154 - kl_loss: 107.3553 - mean_squared_error: 0.0283 - classification_loss: 1.6315
# Epoch 68/500
#  - 32s - loss: 6038.4251 - r_loss: 5928.9087 - kl_loss: 107.9048 - mean_squared_error: 0.0282 - classification_loss: 1.6121
# Epoch 69/500
#  - 31s - loss: 6033.2387 - r_loss: 5923.3589 - kl_loss: 108.2739 - mean_squared_error: 0.0280 - classification_loss: 1.6061
# Epoch 70/500
#  - 32s - loss: 6028.9323 - r_loss: 5918.8086 - kl_loss: 108.5257 - mean_squared_error: 0.0279 - classification_loss: 1.5975
# Epoch 71/500
#  - 31s - loss: 6030.4871 - r_loss: 5920.0342 - kl_loss: 108.8517 - mean_squared_error: 0.0279 - classification_loss: 1.6006
# Epoch 72/500
#  - 32s - loss: 6028.0384 - r_loss: 5917.7354 - kl_loss: 108.7240 - mean_squared_error: 0.0278 - classification_loss: 1.5794
# Epoch 73/500
#  - 31s - loss: 6025.1695 - r_loss: 5914.1177 - kl_loss: 109.4772 - mean_squared_error: 0.0277 - classification_loss: 1.5745
# Epoch 74/500
#  - 32s - loss: 6019.8890 - r_loss: 5908.7690 - kl_loss: 109.5620 - mean_squared_error: 0.0275 - classification_loss: 1.5573
# Epoch 75/500
#  - 32s - loss: 6021.6237 - r_loss: 5910.1318 - kl_loss: 109.9347 - mean_squared_error: 0.0276 - classification_loss: 1.5566
# Epoch 76/500
#  - 32s - loss: 6013.9748 - r_loss: 5902.1743 - kl_loss: 110.2563 - mean_squared_error: 0.0273 - classification_loss: 1.5431
# Epoch 77/500
#  - 31s - loss: 6010.6577 - r_loss: 5898.3198 - kl_loss: 110.7927 - mean_squared_error: 0.0272 - classification_loss: 1.5452
# Epoch 78/500
#  - 32s - loss: 6007.0757 - r_loss: 5894.1030 - kl_loss: 111.4306 - mean_squared_error: 0.0271 - classification_loss: 1.5410
# Epoch 79/500
#  - 31s - loss: 6004.5736 - r_loss: 5891.0273 - kl_loss: 112.0144 - mean_squared_error: 0.0270 - classification_loss: 1.5315
# Epoch 80/500
#  - 32s - loss: 6000.8360 - r_loss: 5886.7920 - kl_loss: 112.5128 - mean_squared_error: 0.0268 - classification_loss: 1.5308
# Epoch 81/500
#  - 31s - loss: 5999.1156 - r_loss: 5885.0806 - kl_loss: 112.5010 - mean_squared_error: 0.0268 - classification_loss: 1.5335
# Epoch 82/500
#  - 32s - loss: 5996.5236 - r_loss: 5881.0811 - kl_loss: 113.8770 - mean_squared_error: 0.0266 - classification_loss: 1.5651
# Epoch 83/500
#  - 31s - loss: 5989.0463 - r_loss: 5874.0439 - kl_loss: 113.4828 - mean_squared_error: 0.0264 - classification_loss: 1.5209
# Epoch 84/500
#  - 31s - loss: 5987.8051 - r_loss: 5872.3149 - kl_loss: 113.9854 - mean_squared_error: 0.0264 - classification_loss: 1.5046
# Epoch 85/500
#  - 32s - loss: 5986.2778 - r_loss: 5870.5952 - kl_loss: 114.1902 - mean_squared_error: 0.0263 - classification_loss: 1.4924
# Epoch 86/500
#  - 32s - loss: 5980.9131 - r_loss: 5865.0815 - kl_loss: 114.3516 - mean_squared_error: 0.0262 - classification_loss: 1.4795
# Epoch 87/500
#  - 32s - loss: 5981.8753 - r_loss: 5865.7197 - kl_loss: 114.6846 - mean_squared_error: 0.0262 - classification_loss: 1.4726
# Epoch 88/500
#  - 32s - loss: 5980.4442 - r_loss: 5864.0874 - kl_loss: 114.8989 - mean_squared_error: 0.0261 - classification_loss: 1.4582
# Epoch 89/500
#  - 32s - loss: 5977.1843 - r_loss: 5860.5674 - kl_loss: 115.1703 - mean_squared_error: 0.0260 - classification_loss: 1.4471
# Epoch 90/500
#  - 31s - loss: 5972.4975 - r_loss: 5855.7451 - kl_loss: 115.3003 - mean_squared_error: 0.0259 - classification_loss: 1.4517
# Epoch 91/500
#  - 31s - loss: 5975.2306 - r_loss: 5858.1079 - kl_loss: 115.6810 - mean_squared_error: 0.0260 - classification_loss: 1.4418
# Epoch 92/500
#  - 32s - loss: 5973.6560 - r_loss: 5856.1177 - kl_loss: 116.1060 - mean_squared_error: 0.0259 - classification_loss: 1.4300
# Epoch 93/500
#  - 32s - loss: 5965.3188 - r_loss: 5847.7749 - kl_loss: 116.1196 - mean_squared_error: 0.0256 - classification_loss: 1.4246
# Epoch 94/500
#  - 32s - loss: 5968.7740 - r_loss: 5851.3159 - kl_loss: 116.0388 - mean_squared_error: 0.0257 - classification_loss: 1.4195
# Epoch 95/500
#  - 32s - loss: 5968.0170 - r_loss: 5850.4600 - kl_loss: 116.1434 - mean_squared_error: 0.0257 - classification_loss: 1.4136
# Epoch 96/500
#  - 31s - loss: 5964.6276 - r_loss: 5846.0303 - kl_loss: 117.1995 - mean_squared_error: 0.0256 - classification_loss: 1.3989
# Epoch 97/500
#  - 31s - loss: 5959.8900 - r_loss: 5841.3984 - kl_loss: 117.0974 - mean_squared_error: 0.0254 - classification_loss: 1.3938
# Epoch 98/500
#  - 32s - loss: 5983.9741 - r_loss: 5866.1099 - kl_loss: 116.4617 - mean_squared_error: 0.0262 - classification_loss: 1.4028
# Epoch 99/500
#  - 32s - loss: 5962.6439 - r_loss: 5844.1851 - kl_loss: 117.0854 - mean_squared_error: 0.0255 - classification_loss: 1.3738
# Epoch 100/500
#  - 31s - loss: 5958.1072 - r_loss: 5839.2881 - kl_loss: 117.4497 - mean_squared_error: 0.0254 - classification_loss: 1.3695
# Epoch 101/500
#  - 32s - loss: 5959.6442 - r_loss: 5841.2485 - kl_loss: 117.0290 - mean_squared_error: 0.0254 - classification_loss: 1.3659
# Epoch 102/500
#  - 31s - loss: 5955.3298 - r_loss: 5836.1914 - kl_loss: 117.7862 - mean_squared_error: 0.0253 - classification_loss: 1.3520
# Epoch 103/500
#  - 32s - loss: 5953.4477 - r_loss: 5834.5293 - kl_loss: 117.5622 - mean_squared_error: 0.0252 - classification_loss: 1.3565
# Epoch 104/500
#  - 32s - loss: 5954.4117 - r_loss: 5834.9946 - kl_loss: 118.0728 - mean_squared_error: 0.0252 - classification_loss: 1.3444
# Epoch 105/500
#  - 32s - loss: 5952.3979 - r_loss: 5832.9819 - kl_loss: 118.0755 - mean_squared_error: 0.0252 - classification_loss: 1.3413
# Epoch 106/500
#  - 32s - loss: 5951.8113 - r_loss: 5832.4443 - kl_loss: 118.0375 - mean_squared_error: 0.0252 - classification_loss: 1.3293
# Epoch 107/500
#  - 31s - loss: 5949.9568 - r_loss: 5830.2305 - kl_loss: 118.4054 - mean_squared_error: 0.0251 - classification_loss: 1.3213
# Epoch 108/500
#  - 32s - loss: 5949.2362 - r_loss: 5829.7817 - kl_loss: 118.1332 - mean_squared_error: 0.0251 - classification_loss: 1.3213
# Epoch 109/500
#  - 32s - loss: 5950.5840 - r_loss: 5830.3955 - kl_loss: 118.8768 - mean_squared_error: 0.0251 - classification_loss: 1.3127
# Epoch 110/500
#  - 32s - loss: 5948.7426 - r_loss: 5828.5430 - kl_loss: 118.8942 - mean_squared_error: 0.0251 - classification_loss: 1.3061
# Epoch 111/500
#  - 31s - loss: 5944.9293 - r_loss: 5824.6016 - kl_loss: 119.0239 - mean_squared_error: 0.0249 - classification_loss: 1.3036
# Epoch 112/500
#  - 30s - loss: 5946.4473 - r_loss: 5826.2017 - kl_loss: 118.9531 - mean_squared_error: 0.0250 - classification_loss: 1.2923
# Epoch 113/500
#  - 31s - loss: 5943.8194 - r_loss: 5823.1626 - kl_loss: 119.3671 - mean_squared_error: 0.0249 - classification_loss: 1.2895
# Epoch 114/500
#  - 32s - loss: 5945.3713 - r_loss: 5824.6938 - kl_loss: 119.3892 - mean_squared_error: 0.0250 - classification_loss: 1.2885
# Epoch 115/500
#  - 31s - loss: 5942.8186 - r_loss: 5822.4717 - kl_loss: 119.0714 - mean_squared_error: 0.0249 - classification_loss: 1.2756
# Epoch 116/500
#  - 31s - loss: 5945.9260 - r_loss: 5825.2168 - kl_loss: 119.4369 - mean_squared_error: 0.0250 - classification_loss: 1.2729
# Epoch 117/500
#  - 31s - loss: 5939.9436 - r_loss: 5818.9692 - kl_loss: 119.7119 - mean_squared_error: 0.0248 - classification_loss: 1.2627
# Epoch 118/500
#  - 31s - loss: 5939.3017 - r_loss: 5817.9521 - kl_loss: 120.0964 - mean_squared_error: 0.0248 - classification_loss: 1.2523
# Epoch 119/500
#  - 32s - loss: 5938.7777 - r_loss: 5817.7158 - kl_loss: 119.8049 - mean_squared_error: 0.0247 - classification_loss: 1.2569
# Epoch 120/500
#  - 32s - loss: 5938.4209 - r_loss: 5817.0400 - kl_loss: 120.1258 - mean_squared_error: 0.0247 - classification_loss: 1.2559
# Epoch 121/500
#  - 32s - loss: 5939.3742 - r_loss: 5818.5479 - kl_loss: 119.5675 - mean_squared_error: 0.0248 - classification_loss: 1.2595
# Epoch 122/500
#  - 32s - loss: 5937.8008 - r_loss: 5816.5742 - kl_loss: 119.9906 - mean_squared_error: 0.0247 - classification_loss: 1.2367
# Epoch 123/500
#  - 32s - loss: 5937.8562 - r_loss: 5816.9067 - kl_loss: 119.7160 - mean_squared_error: 0.0247 - classification_loss: 1.2345
# Epoch 124/500
#  - 32s - loss: 5935.4334 - r_loss: 5814.1426 - kl_loss: 120.0527 - mean_squared_error: 0.0246 - classification_loss: 1.2371
# Epoch 125/500
#  - 32s - loss: 5934.7906 - r_loss: 5813.2046 - kl_loss: 120.3604 - mean_squared_error: 0.0246 - classification_loss: 1.2254
# Epoch 126/500
#  - 32s - loss: 5935.2773 - r_loss: 5813.7998 - kl_loss: 120.2581 - mean_squared_error: 0.0246 - classification_loss: 1.2187
# Epoch 127/500
#  - 32s - loss: 5933.8090 - r_loss: 5812.0234 - kl_loss: 120.5667 - mean_squared_error: 0.0246 - classification_loss: 1.2197
# Epoch 128/500
#  - 31s - loss: 5932.6075 - r_loss: 5810.2798 - kl_loss: 121.1219 - mean_squared_error: 0.0245 - classification_loss: 1.2062
# Epoch 129/500
#  - 31s - loss: 5930.7265 - r_loss: 5808.4727 - kl_loss: 121.0544 - mean_squared_error: 0.0245 - classification_loss: 1.2001
# Epoch 130/500
#  - 32s - loss: 5930.3557 - r_loss: 5807.9731 - kl_loss: 121.1733 - mean_squared_error: 0.0245 - classification_loss: 1.2098
# Epoch 131/500
#  - 31s - loss: 5928.2277 - r_loss: 5805.1616 - kl_loss: 121.8566 - mean_squared_error: 0.0245 - classification_loss: 1.2091
# Epoch 132/500
#  - 31s - loss: 5924.8170 - r_loss: 5801.2539 - kl_loss: 122.3610 - mean_squared_error: 0.0244 - classification_loss: 1.2040
# Epoch 133/500
#  - 32s - loss: 5923.2191 - r_loss: 5799.8853 - kl_loss: 122.1416 - mean_squared_error: 0.0244 - classification_loss: 1.1925
# Epoch 134/500
#  - 32s - loss: 5926.4567 - r_loss: 5802.5698 - kl_loss: 122.6922 - mean_squared_error: 0.0245 - classification_loss: 1.1943
# Epoch 135/500
#  - 32s - loss: 5922.5410 - r_loss: 5798.9707 - kl_loss: 122.3839 - mean_squared_error: 0.0244 - classification_loss: 1.1857
# Epoch 136/500
#  - 32s - loss: 5924.1928 - r_loss: 5800.2227 - kl_loss: 122.7957 - mean_squared_error: 0.0244 - classification_loss: 1.1742
# Epoch 137/500
#  - 32s - loss: 5926.6489 - r_loss: 5802.8218 - kl_loss: 122.6468 - mean_squared_error: 0.0245 - classification_loss: 1.1806
# Epoch 138/500
#  - 31s - loss: 5919.6736 - r_loss: 5795.6660 - kl_loss: 122.8314 - mean_squared_error: 0.0243 - classification_loss: 1.1752
# Epoch 139/500
#  - 32s - loss: 5917.6438 - r_loss: 5793.2471 - kl_loss: 123.2256 - mean_squared_error: 0.0242 - classification_loss: 1.1710
# Epoch 140/500
#  - 32s - loss: 5922.5662 - r_loss: 5798.8555 - kl_loss: 122.5386 - mean_squared_error: 0.0244 - classification_loss: 1.1708
# Epoch 141/500
#  - 32s - loss: 5918.4377 - r_loss: 5794.1343 - kl_loss: 123.1427 - mean_squared_error: 0.0242 - classification_loss: 1.1605
# Epoch 142/500
#  - 31s - loss: 5916.6047 - r_loss: 5792.4023 - kl_loss: 123.0554 - mean_squared_error: 0.0242 - classification_loss: 1.1468
# Epoch 143/500
#  - 33s - loss: 5916.2178 - r_loss: 5791.4277 - kl_loss: 123.6431 - mean_squared_error: 0.0241 - classification_loss: 1.1467
# Epoch 144/500
#  - 31s - loss: 5913.7311 - r_loss: 5789.1201 - kl_loss: 123.4609 - mean_squared_error: 0.0241 - classification_loss: 1.1506
# Epoch 145/500
#  - 32s - loss: 5916.4328 - r_loss: 5792.0103 - kl_loss: 123.2689 - mean_squared_error: 0.0242 - classification_loss: 1.1540
# Epoch 146/500
#  - 32s - loss: 5913.6018 - r_loss: 5789.2065 - kl_loss: 123.2516 - mean_squared_error: 0.0241 - classification_loss: 1.1438
# Epoch 147/500
#  - 32s - loss: 5913.1158 - r_loss: 5788.4614 - kl_loss: 123.5160 - mean_squared_error: 0.0241 - classification_loss: 1.1379
# Epoch 148/500
#  - 31s - loss: 5912.7909 - r_loss: 5787.8535 - kl_loss: 123.8085 - mean_squared_error: 0.0240 - classification_loss: 1.1287
# Epoch 149/500
#  - 31s - loss: 5911.7939 - r_loss: 5787.1714 - kl_loss: 123.4929 - mean_squared_error: 0.0240 - classification_loss: 1.1297
# Epoch 150/500
#  - 31s - loss: 5912.0411 - r_loss: 5787.3008 - kl_loss: 123.6176 - mean_squared_error: 0.0240 - classification_loss: 1.1222
# Epoch 151/500
#  - 31s - loss: 5910.5876 - r_loss: 5785.7598 - kl_loss: 123.6988 - mean_squared_error: 0.0240 - classification_loss: 1.1289
# Epoch 152/500
#  - 31s - loss: 5913.0767 - r_loss: 5788.3003 - kl_loss: 123.6568 - mean_squared_error: 0.0241 - classification_loss: 1.1201
# Epoch 153/500
#  - 31s - loss: 5910.5165 - r_loss: 5786.1143 - kl_loss: 123.2952 - mean_squared_error: 0.0240 - classification_loss: 1.1071
# Epoch 154/500
#  - 31s - loss: 5911.9715 - r_loss: 5787.1670 - kl_loss: 123.7002 - mean_squared_error: 0.0240 - classification_loss: 1.1039
# Epoch 155/500
#  - 32s - loss: 5911.2241 - r_loss: 5786.5518 - kl_loss: 123.5704 - mean_squared_error: 0.0240 - classification_loss: 1.1031
# Epoch 156/500
#  - 32s - loss: 5910.6044 - r_loss: 5786.1055 - kl_loss: 123.3938 - mean_squared_error: 0.0240 - classification_loss: 1.1055
# Epoch 157/500
#  - 30s - loss: 5912.6117 - r_loss: 5788.1084 - kl_loss: 123.4087 - mean_squared_error: 0.0241 - classification_loss: 1.0954
# Epoch 158/500
#  - 32s - loss: 5910.0632 - r_loss: 5785.0601 - kl_loss: 123.9117 - mean_squared_error: 0.0240 - classification_loss: 1.0910
# Epoch 159/500
#  - 31s - loss: 5911.3655 - r_loss: 5786.4336 - kl_loss: 123.8341 - mean_squared_error: 0.0240 - classification_loss: 1.0978
# Epoch 160/500
#  - 31s - loss: 5907.2774 - r_loss: 5782.1675 - kl_loss: 124.0208 - mean_squared_error: 0.0239 - classification_loss: 1.0887
# Epoch 161/500
#  - 31s - loss: 5908.7460 - r_loss: 5783.9336 - kl_loss: 123.7221 - mean_squared_error: 0.0239 - classification_loss: 1.0905
# Epoch 162/500
#  - 31s - loss: 5907.9011 - r_loss: 5782.7876 - kl_loss: 124.0232 - mean_squared_error: 0.0239 - classification_loss: 1.0907
# Epoch 163/500
#  - 32s - loss: 5910.9177 - r_loss: 5786.4692 - kl_loss: 123.3640 - mean_squared_error: 0.0240 - classification_loss: 1.0853
# Epoch 164/500
#  - 32s - loss: 5906.8542 - r_loss: 5781.6919 - kl_loss: 124.0871 - mean_squared_error: 0.0239 - classification_loss: 1.0738
# Epoch 165/500
#  - 32s - loss: 5908.5171 - r_loss: 5783.6460 - kl_loss: 123.7919 - mean_squared_error: 0.0239 - classification_loss: 1.0790
# Epoch 166/500
#  - 32s - loss: 5911.4404 - r_loss: 5786.5454 - kl_loss: 123.8201 - mean_squared_error: 0.0240 - classification_loss: 1.0758
# Epoch 167/500
#  - 31s - loss: 5903.5505 - r_loss: 5778.2290 - kl_loss: 124.2553 - mean_squared_error: 0.0238 - classification_loss: 1.0670
# Epoch 168/500
#  - 32s - loss: 5902.9642 - r_loss: 5777.8115 - kl_loss: 124.0891 - mean_squared_error: 0.0237 - classification_loss: 1.0625
# Epoch 169/500
#  - 31s - loss: 5905.1478 - r_loss: 5780.0000 - kl_loss: 124.0778 - mean_squared_error: 0.0238 - classification_loss: 1.0696
# Epoch 170/500
#  - 31s - loss: 5905.8409 - r_loss: 5780.3965 - kl_loss: 124.3838 - mean_squared_error: 0.0238 - classification_loss: 1.0601
# Epoch 171/500
#  - 31s - loss: 5904.1361 - r_loss: 5778.6021 - kl_loss: 124.4776 - mean_squared_error: 0.0238 - classification_loss: 1.0557
# Epoch 172/500
#  - 31s - loss: 5909.5295 - r_loss: 5784.2964 - kl_loss: 124.1793 - mean_squared_error: 0.0240 - classification_loss: 1.0546
# Epoch 173/500
#  - 32s - loss: 5903.9306 - r_loss: 5778.7578 - kl_loss: 124.1174 - mean_squared_error: 0.0238 - classification_loss: 1.0559
# Epoch 174/500
#  - 31s - loss: 5903.1060 - r_loss: 5777.4634 - kl_loss: 124.5864 - mean_squared_error: 0.0237 - classification_loss: 1.0564
# Epoch 175/500
#  - 32s - loss: 5905.4344 - r_loss: 5779.8057 - kl_loss: 124.5868 - mean_squared_error: 0.0238 - classification_loss: 1.0421
# Epoch 176/500
#  - 31s - loss: 5904.1936 - r_loss: 5778.9082 - kl_loss: 124.2433 - mean_squared_error: 0.0238 - classification_loss: 1.0421
# Epoch 177/500
#  - 32s - loss: 5902.3941 - r_loss: 5776.7041 - kl_loss: 124.6474 - mean_squared_error: 0.0237 - classification_loss: 1.0417
# Epoch 178/500
#  - 31s - loss: 5903.7565 - r_loss: 5778.2222 - kl_loss: 124.4947 - mean_squared_error: 0.0238 - classification_loss: 1.0394
# Epoch 179/500
#  - 32s - loss: 5900.8360 - r_loss: 5775.4395 - kl_loss: 124.3644 - mean_squared_error: 0.0237 - classification_loss: 1.0316
# Epoch 180/500
#  - 31s - loss: 5901.5441 - r_loss: 5775.8794 - kl_loss: 124.6366 - mean_squared_error: 0.0237 - classification_loss: 1.0288
# Epoch 181/500
#  - 32s - loss: 5901.2889 - r_loss: 5775.6377 - kl_loss: 124.6168 - mean_squared_error: 0.0237 - classification_loss: 1.0344
# Epoch 182/500
#  - 31s - loss: 5901.0146 - r_loss: 5775.1357 - kl_loss: 124.8502 - mean_squared_error: 0.0237 - classification_loss: 1.0284
# Epoch 183/500
#  - 31s - loss: 5902.7492 - r_loss: 5777.3369 - kl_loss: 124.3895 - mean_squared_error: 0.0237 - classification_loss: 1.0228
# Epoch 184/500
#  - 31s - loss: 5902.9912 - r_loss: 5777.3198 - kl_loss: 124.6404 - mean_squared_error: 0.0237 - classification_loss: 1.0300
# Epoch 185/500
#  - 31s - loss: 5900.0876 - r_loss: 5774.5381 - kl_loss: 124.5277 - mean_squared_error: 0.0237 - classification_loss: 1.0211
# Epoch 186/500
#  - 32s - loss: 5902.5740 - r_loss: 5776.8945 - kl_loss: 124.6619 - mean_squared_error: 0.0237 - classification_loss: 1.0185
# Epoch 187/500
#  - 32s - loss: 5903.1198 - r_loss: 5778.0078 - kl_loss: 124.0929 - mean_squared_error: 0.0238 - classification_loss: 1.0189
# Epoch 188/500
#  - 32s - loss: 5899.6683 - r_loss: 5773.5649 - kl_loss: 125.0944 - mean_squared_error: 0.0236 - classification_loss: 1.0098
# Epoch 189/500
#  - 32s - loss: 5902.7852 - r_loss: 5776.7261 - kl_loss: 125.0427 - mean_squared_error: 0.0237 - classification_loss: 1.0159
# Epoch 190/500
#  - 31s - loss: 5897.7011 - r_loss: 5771.7690 - kl_loss: 124.9235 - mean_squared_error: 0.0236 - classification_loss: 1.0090
# Epoch 191/500
#  - 31s - loss: 5897.3519 - r_loss: 5771.5767 - kl_loss: 124.7734 - mean_squared_error: 0.0236 - classification_loss: 1.0021
# Epoch 192/500
#  - 32s - loss: 5896.8932 - r_loss: 5770.9839 - kl_loss: 124.9024 - mean_squared_error: 0.0235 - classification_loss: 1.0071
# Epoch 193/500
#  - 31s - loss: 5897.8988 - r_loss: 5772.3018 - kl_loss: 124.5982 - mean_squared_error: 0.0236 - classification_loss: 0.9981
# Epoch 194/500
#  - 31s - loss: 5895.9901 - r_loss: 5769.7915 - kl_loss: 125.1993 - mean_squared_error: 0.0235 - classification_loss: 0.9989
# Epoch 195/500
#  - 31s - loss: 5898.3809 - r_loss: 5772.5366 - kl_loss: 124.8524 - mean_squared_error: 0.0236 - classification_loss: 0.9912
# Epoch 196/500
#  - 31s - loss: 5896.9335 - r_loss: 5770.9790 - kl_loss: 124.9607 - mean_squared_error: 0.0236 - classification_loss: 0.9942
# Epoch 197/500
#  - 32s - loss: 5899.0567 - r_loss: 5773.5024 - kl_loss: 124.5649 - mean_squared_error: 0.0236 - classification_loss: 0.9895
# Epoch 198/500
#  - 32s - loss: 5897.8296 - r_loss: 5772.1797 - kl_loss: 124.6628 - mean_squared_error: 0.0236 - classification_loss: 0.9872
# Epoch 199/500
#  - 32s - loss: 5898.0303 - r_loss: 5772.1816 - kl_loss: 124.8581 - mean_squared_error: 0.0236 - classification_loss: 0.9904
# Epoch 200/500
#  - 32s - loss: 5897.5813 - r_loss: 5771.4341 - kl_loss: 125.1660 - mean_squared_error: 0.0236 - classification_loss: 0.9806
# Epoch 201/500
#  - 32s - loss: 5896.8979 - r_loss: 5770.9062 - kl_loss: 125.0098 - mean_squared_error: 0.0236 - classification_loss: 0.9819
# Epoch 202/500
#  - 32s - loss: 5891.9147 - r_loss: 5765.7012 - kl_loss: 125.2363 - mean_squared_error: 0.0234 - classification_loss: 0.9779
# Epoch 203/500
#  - 31s - loss: 5897.4310 - r_loss: 5771.6157 - kl_loss: 124.8438 - mean_squared_error: 0.0236 - classification_loss: 0.9704
# Epoch 204/500
#  - 31s - loss: 5896.8551 - r_loss: 5770.6240 - kl_loss: 125.2563 - mean_squared_error: 0.0236 - classification_loss: 0.9752
# Epoch 205/500
#  - 32s - loss: 5896.8065 - r_loss: 5770.6157 - kl_loss: 125.2221 - mean_squared_error: 0.0236 - classification_loss: 0.9683
# Epoch 206/500
#  - 32s - loss: 5894.5042 - r_loss: 5768.0630 - kl_loss: 125.4798 - mean_squared_error: 0.0235 - classification_loss: 0.9628
# Epoch 207/500
#  - 31s - loss: 5895.1417 - r_loss: 5768.7456 - kl_loss: 125.4371 - mean_squared_error: 0.0235 - classification_loss: 0.9584
# Epoch 208/500
#  - 31s - loss: 5893.4127 - r_loss: 5767.4277 - kl_loss: 125.0202 - mean_squared_error: 0.0235 - classification_loss: 0.9653
# Epoch 209/500
#  - 32s - loss: 5895.3764 - r_loss: 5768.7437 - kl_loss: 125.6710 - mean_squared_error: 0.0235 - classification_loss: 0.9609
# Epoch 210/500
#  - 32s - loss: 5894.3985 - r_loss: 5767.8643 - kl_loss: 125.5766 - mean_squared_error: 0.0235 - classification_loss: 0.9570
# Epoch 211/500
#  - 32s - loss: 5892.2292 - r_loss: 5765.9458 - kl_loss: 125.3326 - mean_squared_error: 0.0234 - classification_loss: 0.9509
# Epoch 212/500
#  - 32s - loss: 5895.4232 - r_loss: 5769.0356 - kl_loss: 125.4337 - mean_squared_error: 0.0235 - classification_loss: 0.9542
# Epoch 213/500
#  - 32s - loss: 5892.5571 - r_loss: 5765.9062 - kl_loss: 125.7003 - mean_squared_error: 0.0234 - classification_loss: 0.9509
# Epoch 214/500
#  - 32s - loss: 5894.4563 - r_loss: 5767.8550 - kl_loss: 125.6531 - mean_squared_error: 0.0235 - classification_loss: 0.9485
# Epoch 215/500
#  - 32s - loss: 5892.4744 - r_loss: 5765.8940 - kl_loss: 125.6348 - mean_squared_error: 0.0234 - classification_loss: 0.9462
# Epoch 216/500
#  - 32s - loss: 5892.0126 - r_loss: 5765.4902 - kl_loss: 125.5852 - mean_squared_error: 0.0234 - classification_loss: 0.9380
# Epoch 217/500
#  - 32s - loss: 5892.8463 - r_loss: 5766.0532 - kl_loss: 125.8484 - mean_squared_error: 0.0234 - classification_loss: 0.9453
# Epoch 218/500
#  - 32s - loss: 5891.2264 - r_loss: 5764.7051 - kl_loss: 125.5847 - mean_squared_error: 0.0234 - classification_loss: 0.9376
# Epoch 219/500
#  - 31s - loss: 5889.9075 - r_loss: 5763.4609 - kl_loss: 125.5176 - mean_squared_error: 0.0233 - classification_loss: 0.9295
# Epoch 220/500
#  - 32s - loss: 5893.0570 - r_loss: 5766.4995 - kl_loss: 125.6294 - mean_squared_error: 0.0234 - classification_loss: 0.9286
# Epoch 221/500
#  - 32s - loss: 5891.3076 - r_loss: 5764.8999 - kl_loss: 125.4746 - mean_squared_error: 0.0234 - classification_loss: 0.9329
# Epoch 222/500
#  - 31s - loss: 5890.6845 - r_loss: 5763.8042 - kl_loss: 125.9517 - mean_squared_error: 0.0233 - classification_loss: 0.9285
# Epoch 223/500
#  - 32s - loss: 5889.0322 - r_loss: 5762.6812 - kl_loss: 125.4191 - mean_squared_error: 0.0233 - classification_loss: 0.9305
# Epoch 224/500
#  - 31s - loss: 5892.0480 - r_loss: 5765.2485 - kl_loss: 125.8775 - mean_squared_error: 0.0234 - classification_loss: 0.9219
# Epoch 225/500
#  - 32s - loss: 5889.2680 - r_loss: 5762.5933 - kl_loss: 125.7390 - mean_squared_error: 0.0233 - classification_loss: 0.9365
# Epoch 226/500
#  - 32s - loss: 5888.8707 - r_loss: 5761.9766 - kl_loss: 125.9753 - mean_squared_error: 0.0233 - classification_loss: 0.9181
# Epoch 227/500
#  - 31s - loss: 5889.2646 - r_loss: 5762.6587 - kl_loss: 125.6875 - mean_squared_error: 0.0233 - classification_loss: 0.9185
# Epoch 228/500
#  - 32s - loss: 5888.0678 - r_loss: 5761.2729 - kl_loss: 125.8707 - mean_squared_error: 0.0233 - classification_loss: 0.9234
# Epoch 229/500
#  - 31s - loss: 5893.6856 - r_loss: 5767.2729 - kl_loss: 125.4910 - mean_squared_error: 0.0235 - classification_loss: 0.9199
# Epoch 230/500
#  - 31s - loss: 5890.7813 - r_loss: 5764.0420 - kl_loss: 125.8208 - mean_squared_error: 0.0234 - classification_loss: 0.9171
# Epoch 231/500
#  - 32s - loss: 5887.8251 - r_loss: 5761.2314 - kl_loss: 125.6797 - mean_squared_error: 0.0233 - classification_loss: 0.9150
# Epoch 232/500
#  - 32s - loss: 5893.5117 - r_loss: 5766.5356 - kl_loss: 126.0645 - mean_squared_error: 0.0234 - classification_loss: 0.9113
# Epoch 233/500
#  - 31s - loss: 5891.1428 - r_loss: 5764.2847 - kl_loss: 125.9455 - mean_squared_error: 0.0234 - classification_loss: 0.9124
# Epoch 234/500
#  - 32s - loss: 5886.8157 - r_loss: 5760.0684 - kl_loss: 125.8361 - mean_squared_error: 0.0232 - classification_loss: 0.9091
# Epoch 235/500
#  - 32s - loss: 5888.6893 - r_loss: 5761.7642 - kl_loss: 126.0213 - mean_squared_error: 0.0233 - classification_loss: 0.9052
# Epoch 236/500
#  - 31s - loss: 5889.7343 - r_loss: 5762.8628 - kl_loss: 125.9670 - mean_squared_error: 0.0233 - classification_loss: 0.9051
# Epoch 237/500
#  - 32s - loss: 5888.8573 - r_loss: 5762.2798 - kl_loss: 125.6728 - mean_squared_error: 0.0233 - classification_loss: 0.9037
# Epoch 238/500
#  - 31s - loss: 5886.9686 - r_loss: 5759.9580 - kl_loss: 126.1099 - mean_squared_error: 0.0232 - classification_loss: 0.9002
# Epoch 239/500
#  - 32s - loss: 5888.0750 - r_loss: 5761.1440 - kl_loss: 126.0283 - mean_squared_error: 0.0233 - classification_loss: 0.9025
# Epoch 240/500
#  - 32s - loss: 5886.5983 - r_loss: 5759.3125 - kl_loss: 126.3931 - mean_squared_error: 0.0232 - classification_loss: 0.8927
# Epoch 241/500
#  - 32s - loss: 5888.3207 - r_loss: 5761.2744 - kl_loss: 126.1510 - mean_squared_error: 0.0233 - classification_loss: 0.8948
# Epoch 242/500
#  - 32s - loss: 5895.5173 - r_loss: 5768.7651 - kl_loss: 125.8578 - mean_squared_error: 0.0235 - classification_loss: 0.8944
# Epoch 243/500
#  - 32s - loss: 5885.7953 - r_loss: 5758.8501 - kl_loss: 126.0556 - mean_squared_error: 0.0232 - classification_loss: 0.8908
# Epoch 244/500
#  - 32s - loss: 5887.0266 - r_loss: 5759.7690 - kl_loss: 126.3768 - mean_squared_error: 0.0232 - classification_loss: 0.8819
# Epoch 245/500
#  - 32s - loss: 5887.7648 - r_loss: 5760.1494 - kl_loss: 126.7303 - mean_squared_error: 0.0233 - classification_loss: 0.8850
# Epoch 246/500
#  - 31s - loss: 5888.3772 - r_loss: 5761.0425 - kl_loss: 126.4445 - mean_squared_error: 0.0233 - classification_loss: 0.8902
# Epoch 247/500
#  - 32s - loss: 5883.8925 - r_loss: 5756.7285 - kl_loss: 126.2814 - mean_squared_error: 0.0232 - classification_loss: 0.8829
# Epoch 248/500
#  - 32s - loss: 5888.0795 - r_loss: 5760.9194 - kl_loss: 126.2742 - mean_squared_error: 0.0233 - classification_loss: 0.8857
# Epoch 249/500
#  - 32s - loss: 5883.4299 - r_loss: 5756.0664 - kl_loss: 126.4849 - mean_squared_error: 0.0231 - classification_loss: 0.8779
# Epoch 250/500
#  - 32s - loss: 5887.2732 - r_loss: 5760.3281 - kl_loss: 126.0659 - mean_squared_error: 0.0233 - classification_loss: 0.8793
# Epoch 251/500
#  - 31s - loss: 5885.8376 - r_loss: 5758.3149 - kl_loss: 126.6500 - mean_squared_error: 0.0232 - classification_loss: 0.8728
# Epoch 252/500
#  - 32s - loss: 5890.0802 - r_loss: 5762.9702 - kl_loss: 126.2349 - mean_squared_error: 0.0233 - classification_loss: 0.8742
# Epoch 253/500
#  - 32s - loss: 5885.9512 - r_loss: 5758.1162 - kl_loss: 126.9562 - mean_squared_error: 0.0232 - classification_loss: 0.8786
# Epoch 254/500
#  - 31s - loss: 5886.1894 - r_loss: 5758.4102 - kl_loss: 126.8968 - mean_squared_error: 0.0232 - classification_loss: 0.8833
# Epoch 255/500
#  - 32s - loss: 5884.7841 - r_loss: 5757.2080 - kl_loss: 126.6990 - mean_squared_error: 0.0232 - classification_loss: 0.8769
# Epoch 256/500
#  - 32s - loss: 5884.7475 - r_loss: 5757.5889 - kl_loss: 126.2887 - mean_squared_error: 0.0232 - classification_loss: 0.8706
# Epoch 257/500
#  - 32s - loss: 5883.1563 - r_loss: 5755.7104 - kl_loss: 126.5776 - mean_squared_error: 0.0231 - classification_loss: 0.8695
# Epoch 258/500
#  - 31s - loss: 5882.7651 - r_loss: 5755.2544 - kl_loss: 126.6475 - mean_squared_error: 0.0231 - classification_loss: 0.8626
# Epoch 259/500
#  - 31s - loss: 5884.7802 - r_loss: 5756.9937 - kl_loss: 126.9201 - mean_squared_error: 0.0232 - classification_loss: 0.8652
# Epoch 260/500
#  - 31s - loss: 5883.1368 - r_loss: 5755.5869 - kl_loss: 126.6818 - mean_squared_error: 0.0231 - classification_loss: 0.8681
# Epoch 261/500
#  - 32s - loss: 5884.3385 - r_loss: 5756.9883 - kl_loss: 126.4853 - mean_squared_error: 0.0232 - classification_loss: 0.8643
# Epoch 262/500
#  - 32s - loss: 5884.7532 - r_loss: 5757.4253 - kl_loss: 126.4624 - mean_squared_error: 0.0232 - classification_loss: 0.8665
# Epoch 263/500
#  - 32s - loss: 5884.2644 - r_loss: 5757.0308 - kl_loss: 126.3750 - mean_squared_error: 0.0231 - classification_loss: 0.8598
# Epoch 264/500
